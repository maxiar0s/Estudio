# %%
from numpy import array 

n=0

i=0

for i in range(11,12):

  n=i+1

  if n==60:

    print(f'El término en el lugar {n} es {400*n-60}')
m = array([[24,14,11],
           [21,23,18]])

p = array ([[173,167,199],
           [218,180,185],
           [192,163,212]])
e=m.dot(p)

print(e)
# Out:
# [[ 9316  8321  9698]
#  [12103 10581 12250]]
