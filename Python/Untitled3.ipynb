# %%
n=0
i=0

for i in range(20):
  n=i+1
  print(f'a({n})={1/n}')
# Out:
# a(1)=1.0
# a(2)=0.5
# a(3)=0.3333333333333333
# a(4)=0.25
# a(5)=0.2
# a(6)=0.16666666666666666
# a(7)=0.14285714285714285
# a(8)=0.125
# a(9)=0.1111111111111111
# a(10)=0.1
# a(11)=0.09090909090909091
# a(12)=0.08333333333333333
# a(13)=0.07692307692307693
# a(14)=0.07142857142857142
# a(15)=0.06666666666666667
# a(16)=0.0625
# a(17)=0.058823529411764705
# a(18)=0.05555555555555555
# a(19)=0.05263157894736842
# a(20)=0.05
