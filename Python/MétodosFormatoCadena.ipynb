# %% [markdown]
# # **Métodos de formatos de cadenas**
#
# **Convertir una cadena a minúsculas**
#
# **lower()**
#       : retorna una copia de la cadena en minúsculas.

# %%
#Ejemplo:
cadena1 = "Hola Mundo" 
cadena2= cadena1.lower()
print (cadena2)

# %% [markdown]
# **Convertir una cadena a mayúsculas**
#
# **upper()**
#       : retorna una copia de la cadena en mayúsculas.

# %%
#Ejemplo:
cadena1 = "Hola Mundo" 
cadena2= cadena1.upper()
print (cadena2)

# %% [markdown]
# **Convertir a mayúscula la primera letra**
#
# **capitalize()**
#       : retorna una copia de la cadena con la primera letra en mayúsculas.

# %%
#Ejemplo:
cadena1= "bienvenido a mi aplicación" 
cadena2=cadena1.capitalize()
print(cadena2)
# Out:
# Bienvenido a mi aplicación

# %% [markdown]
# **Convertir mayúsculas a minúsculas y viceversa**
#
# **swapcase()**
#       : retorna una copia de la cadena convertidas las mayúsculas en minúsculas y viceversa.

# %%
pago=input("Ingrese metodo de pago \n[E]: Efectivo \n[T]: Tarjeta\n ")
pan=input("Ingrese tipo de pan \n[C]: Corriente \n[S]: Sésamo \n[F]: Frica \n[M]: Molde\n ")
cantidad=input(int("Ingrese cantidad de kilos pan "))
precio=input(int("Ingrese precio del kilo "))
if(pan.lower()=="c" and pago.lower()=="e"):
	corriente=pan*cantidad
	print("\n\tCantidad de kilos: "+str(cantidad)+"\nTipo de pan: Corriente\nTotal descuentos: CERO\nTotal a pagar: "+str(corriente))
# Out:
# Ingrese metodo de pago
# [E]: Efectivo
# [T]: Tarjeta
#  e
# Ingrese tipo de pan
# [C]: Corriente
# [S]: Sésamo
# [F]: Frica
# [M]: Molde
#  c
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-6d0b516504db> in <module>()
#       1 pago=input("Ingrese metodo de pago \n[E]: Efectivo \n[T]: Tarjeta\n ")
#       2 pan=input("Ingrese tipo de pan \n[C]: Corriente \n[S]: Sésamo \n[F]: Frica \n[M]: Molde\n ")
# ----> 3 cantidad=input(int("Ingrese cantidad de kilos pan "))
#       4 precio=input(int("Ingrese precio del kilo "))
#       5 if(pan.lower()=="c" and pago.lower()=="e"):
#
# ValueError: invalid literal for int() with base 10: 'Ingrese cantidad de kilos pan '

# %%
pago=input("Ingrese metodo de pago \n[E]: Efectivo \n[T]: Tarjeta\n ")
pan=input("Ingrese tipo de pan \n[C]: Corriente \n[S]: Sésamo \n[F]: Frica \n[M]: Molde\n ")
cantidad=int(input("Ingrese cantidad de kilos de pan ")
precio=int(input("Ingrese precio del kilo "))
if(pan.lower()=="c" and pago.lower()=="e"):
	corriente=pan*cantidad
	print("\n\tCantidad de kilos: "+str(cantidad)+"\nTipo de pan: Corriente\nTotal descuentos: CERO\nTotal a pagar: "+str(corriente))
# Out:
#   File "<ipython-input-15-3529c2b8a838>", line 4
#     precio=int(input("Ingrese precio del kilo "))
#          ^
# SyntaxError: invalid syntax

# %%
#Ejemplo:
cadena1 = "\n\tHola Mundo" 
cadena2= cadena1. swapcase()
print (cadena2)
# Out:
# 	hOLA mUNDO

# %% [markdown]
# **Convertir una cadena en Formato Título**
#
# **title()**
#       : retorna una copia de la cadena convertida

# %%
#Ejemplo:
cadena1= "hola bienvenidos a Python" 
cadena2= cadena1.title()
print (cadena2)
# Out:
# Hola Bienvenidos A Python

# %% [markdown]
# **Centrar un texto**
#
# **center(longitud[, "caracter de relleno"])**
#       : retorna una copia de la cadena centrada.

# %%
#Ejemplo:
cadena = "bienvenido a mi aplicación".capitalize() 
print(cadena.center(50, "="))
# Out:
# ============Bienvenido a mi aplicación============

# %% [markdown]
# **Alinear texto a la izquierda**
#
# **ljust(longitud[, "caracter de relleno"])**
#       : retorna una copia de la cadena alineada a la izquierda.

# %%
#Ejemplo:
cadena = "bienvenido a mi aplicación".capitalize() 
print(cadena.ljust(50, "="))
# Out:
# Bienvenido a mi aplicación========================

# %% [markdown]
# **Alinear texto a la derecha**
#
# **rjust(longitud[, "caracter de relleno"])**
#       : retorna una copia de la cadena alineada a la derecha.

# %%
#Ejemplo:
cadena = "bienvenido a mi aplicación".capitalize() 
print(cadena.rjust(50, "="))

# %% [markdown]
# **Rellenar un texto anteponiendo ceros**
#
# **zfill(longitud)**
#       : retorna una copia de la cadena rellena con ceros a la izquierda hasta alcanzar la longitud final indicada.

# %%
#Ejemplo:
numero_factura = 1575 
print(str(numero_factura).zfill(12))
# Out:
# 000000001575
