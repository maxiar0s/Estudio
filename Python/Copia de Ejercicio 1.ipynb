# %% [markdown]
#    print("colabority")

# %%
print("Bienvenidos al mundo de Python")
# Out:
# Bienvenidos al mundo de Python

# %%
nom="cosito"
edad=2
peso=4.5
print("Hola "+nom+" como estas?")
print(nom+" pesa "+str(peso)+" Kg y tiene "+str(edad)+" años")
# Out:
# Hola cosito como estas?
# cosito pesa 4.5 Kg y tiene 2 años

# %%
peso=float(input("Ingrese su peso en kg"))
altura=float(input("Ingrese altura en mts"))
imc=peso/altura**2
print("Su IMC es "+str(round(imc,2)))
# Out:
# Ingrese su peso en kg60
# Ingrese altura en mts1.70
# Su IMC es 20.76
